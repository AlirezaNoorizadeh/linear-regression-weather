# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('weatherHistory.csv')

correlation = df[['Apparent Temperature (C)', 'Temperature (C)']].corr()
print("Correlation matrix:\n", correlation)

X = df[['Apparent Temperature (C)']]
y = df['Temperature (C)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")

plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel("Apparent Temperature (C)")
plt.ylabel("Temperature (C)")
plt.title("Linear Regression")
plt.legend()
plt.show()
# Out:
# Correlation matrix:
#                            Apparent Temperature (C)  Temperature (C)
# Apparent Temperature (C)                  1.000000         0.992629
# Temperature (C)                           0.992629         1.000000
# Mean Squared Error (MSE): 1.33
# R-squared (R²): 0.99
